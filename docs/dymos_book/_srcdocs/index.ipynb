# %% [markdown]
# # Source Docs
#
# - [grid_refinement](packages/grid_refinement.md)
# - [grid_refinement.hp_adaptive](packages/grid_refinement.hp_adaptive.md)
# - [grid_refinement.ph_adaptive](packages/grid_refinement.ph_adaptive.md)
# - [models](packages/models.md)
# - [models.atmosphere](packages/models.atmosphere.md)
# - [phase](packages/phase.md)
# - [trajectory](packages/trajectory.md)
# - [transcriptions](packages/transcriptions.md)
# - [transcriptions.common](packages/transcriptions.common.md)
# - [transcriptions.explicit_shooting](packages/transcriptions.explicit_shooting.md)
# - [transcriptions.pseudospectral](packages/transcriptions.pseudospectral.md)
# - [transcriptions.solve_ivp](packages/transcriptions.solve_ivp.md)
# - [utils](packages/utils.md)
